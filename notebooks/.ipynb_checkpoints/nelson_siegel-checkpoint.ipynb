# %%
# %cd "C:\Users\Lenovo\PycharmProjects\Fixed_Income"
# Out:
# C:\Users\Lenovo\PycharmProjects\Fixed_Income

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from utils.visualizations import YieldCurveVisualizer
from models.NelsonSiegel import NelsonSiegel
from utils.bootstrap import BootstrapZeroCurve
plt.style.use('dark_background')

# %%
df = pd.read_csv("data/10_years_data.csv", index_col=0, parse_dates=True)
df.head()
# Out:
#             0.08333333333333333  0.25   0.5   1.0   2.0   3.0   5.0   7.0  \
# 2016-01-04                 0.17  0.22  0.49  0.61  1.02  1.31  1.73  2.06
# 2016-01-05                 0.20  0.20  0.49  0.68  1.04  1.32  1.73  2.06
# 2016-01-06                 0.21  0.21  0.47  0.67  0.99  1.26  1.65  1.98
# 2016-01-07                 0.20  0.20  0.46  0.66  0.96  1.22  1.61  1.94
# 2016-01-08                 0.20  0.20  0.45  0.64  0.94  1.20  1.57  1.91
#
#             10.0  20.0  30.0
# 2016-01-04  2.24  2.64  2.98
# 2016-01-05  2.25  2.67  3.01
# 2016-01-06  2.18  2.59  2.94
# 2016-01-07  2.16  2.56  2.92
# 2016-01-08  2.13  2.55  2.91

# %%
# --- Visualization ---
visualizer = YieldCurveVisualizer()
visualizer.plot_yield_surface(df)

# %%
# --- Nelson-Siegel ---
ns = NelsonSiegel()
visualizer.plot_ns_fit(df, df.index[-1], ns)
# Out:
# beta0 (Level): 5.132, beta1 (Slope): -1.373, beta2 (Curvature): -3.171, lambda: 0.394

# %%
# --- Bootstrapping ---
bootstrap_engine = BootstrapZeroCurve()
bootstrap_engine.plot_bootstrap(df)
# Out:
# Bootstrapped Zero Curve:
